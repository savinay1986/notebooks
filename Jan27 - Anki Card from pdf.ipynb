# %%
import openai
from tqdm.auto import tqdm
import time
import json
openai.api_key = "YOUR_API_KEY_HERE"

# %% [markdown]
# ## Get the text

# %%
paper_title = "Loss of epigenetic information as a cause of mammalian aging"
data = open("epigenome.txt").read()
len(data)
# Out:
# 183187

# %% [markdown]
# ## Chunk the text

# %%
chunks = []
current_chunk = ""

max_tokens = 2048
response_avg_size = 500
max_characters = max_tokens * 4 - response_avg_size


sentences = [x for x in data.split(".") if len(x) > 10]

# doing some chunkings
for i, sentence in enumerate(sentences):
    is_sentence_big = len(sentence) > max_characters
    if is_sentence_big:
        chunks += [current_chunk, sentence]
        current_chunk = ""
        continue

    if len(current_chunk) > max_characters:
        chunks += [current_chunk]
        current_chunk = ""
    current_chunk += sentence + "."
if current_chunk:
    chunks += [current_chunk]

print(f"Number of tokens for each chunk: ")    
print([len(chunk) / 4 for chunk in chunks], max([len(chunk) / 4 for chunk in chunks]))
# Out:
# Number of tokens for each chunk:
# [1934.5, 1966.0, 1969.75, 1954.0, 1986.0, 1977.75, 1952.0, 1941.5, 1925.5, 1926.0, 1934.75, 1935.5, 1954.0, 1923.25, 1946.0, 1949.75, 1926.0, 1936.0, 1983.75, 1933.25, 1924.0, 976.0] 1986.0

# %% [markdown]
# ## Get the first 3 chunks only  (Demo purpose)

# %% [markdown]
# ## GPT-3 To extract important items

# %%
def get_prompt(text):
    prompt = f"""Here is an excerpt from the paper '{paper_title}':\n{text}
Give me the bullet item of specific terms that I should research in order to understand this paper:
- """
    return prompt

def get_response_gpt(prompt):
    is_done = False
    while not is_done:
        try:
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt=prompt,
                temperature=0,
                max_tokens=512,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0
            )
            is_done = True
        except Exception as e:
            print(f"Sleeping for 5 seconds because of {e}")
            time.sleep(5)
    return response["choices"][0]["text"]

# %%
# %%time
responses = []
for chunk in tqdm(chunks):
    prompt = get_prompt(chunk)
    response = get_response_gpt(prompt)
    print(response)
    responses.append(response)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#  DNA breaks
# - Chromatin-modifying proteins
# - Epigenetic landscape
# - Cellular exdifferentiation
# - Senescence
# - DNA methylation clock
# - Information theory of aging
# - Double-stranded DNA breaks (DSBs)
# - Silent information regulator complex (Sir2/3/4)
# - rDNA
# - Sterility
#  DNA methylation
# - Histone modifications
# - DNA sequence
# - DNA damage response
# - Reduced representation bisulfite sequencing (RRBS)
# - Serine-139-phosphorylated H2AX (gH2AX)
# - Senescence-associated b-galactosidase (SA-b-Gal)
# - I-PpoI
# - Tamoxifen (TAM)
# - Estrogen receptor domain gene (ERT2)
# - LoxP-STOP-loxP cassette
# - Cre recombinase gene (Cre-ERT2)
# - Ubiquitin promoter
# - Topoisomerase II inhibitor
# - Phleomycin
# - Ligation-mediated PCR (LM-PCR)
# - Interleukin-6 (IL-6)
# - Ccl2
# - Ccl20
# - Long interspersed nuclear element-1 (LINE-1)
# - Intracisternal A-particle (IAP)
#  Epigenetic Age
# - Whole-Genome Sequencing (WGS)
# - DNA Double-Strand Breaks (DSBs)
# - Senescence-Associated Beta-Galactosidase (SA-b-Gal)
# - Mouse Frailty Index (FI)
# - Epithelial to Mesenchymal Transition (EMT)
# - KIT/CD117-Positive Melanocyte Stem Cells
# - Fear Conditioning
# - Barnes Maze Test
# - Astrocytes
# - Microglia
# - ATP
# - Mitochondrial DNA
#  Cytochrome oxidase (COX)
# -  Repetitive elements
# -  Retrotransposons
# -  Dilated cardiomyopathy
# -  p53-mediated cellular senescence
# -  Myosin light chain 4
# -  NF-kB
# -  Mitochondrial ribosomal protein L55
# -  Epigenetic clocks
# -  Histone levels
# -  Post-translational modifications
# -  H3K122ac
# -  H3K27ac
# -  H3K56ac
# -  Chromatin immunoprecipitation
# -  DNA sequencing (ChIP-seq)
#  Histone Modifications
# -  ChIP-seq
# -  ATAC-seq
# -  H3K27ac
# -  H3K56ac
# -  H3K27me3
# -  CTCF
# -  Homeobox (Hox)
# -  I-PpoI
# -  I-SceI
# -  TreeFam Database
# -  RNA-seq
# -  Hi-C
# -  HiChIP
# -  Topologically Associated Domains (TADs)
# -  Promoter-Enhancer (P-E) Communication
#  Histone Modifications
# -  H3K27me3
# -  H3K27ac
# -  Super-Enhancers
# -  Class II Major Histocompatibility Complex
# -  Yamanaka Factors
# -  Adeno-Associated Virus
# -  Retinal Ganglion Cells
# -  DNA Demethylation
# -  Chromatin Contacts
# -  Hi-C Contact Matrixes
# -  HiChIP Contact Loops
#  Antagonistic Pleiotropy
# -  DNA Damage
# -  DNA Repair
# -  Chromatin Factors
# -  Ten-Eleven Translocation Enzymes (TETs)
# -  DNA Methyltransferases (DNMTs)
# -  Retrotransposons
# -  Induced Pluripotent Stem Cells (iPSCs)
# -  Wnt and Hox Genes
# -  Nucleotide Excision Repair (NER)
# -  Base Excision Repair (BER)
# -  SIRT1
# -  SIRT6
# -  HDAC1
# -  PARP1
# -  Epigenetic Clock
# -  Waddington Valleys
#  rDNA locus
# -  rDNA instability
# -  Nucleolar size
# -  Lifespan
# -  I-SceI
# -  Western blot analysis
# -  Southern blotting
# -  Surveyor assay
# -  Metabolic labeling of MEFs
# -  Quantification of protein synthesis
# -  Quantification of DSBs
# -  Indirect Calorimetry
# -  MMQPCR
# -  Frailty Index assessment
# -  Lens opacity scoring
# -  Magnetic Resonance Imaging
# -  Micro CT scanning
# -  Quantification of optic nerve axons
# -  Immunohistochemistry
# -  Quantification of subepidermal thickness
# -  Brain immunohistochemistry
# -  ATP and mtDNA measurement
# -  Contextual fear conditioning test
# -  Barnes maze test
# -  Grip strength test
# -  Treadmill test
# -  Lactate measurement
# -  Ambulatory activity
# -  Treadmill Gait Analysis
# -  COX and capillary density staining
# -  Electron microscopy
# -  Podocyte density
# -  p57 and PAS representative images
# -  Glomerular Injury
# -  Parietal epithelial cell to mesenchymal transition
# -  5-Ethynyl-2’-deoxyuridine (EdU) staining
# -  Microscopy and imaging for kidney
# -  Immunocytochemistry
# -  Senescence-associated b-galactosidase (SA-bGal) assay
# -  Small molecule-driven neuronal reprogramming
# -  Quantitative real-time PCR for transcription of repetitive elements
# -  Design of PCR primers for repetitive elements
# -  Mutation frequency of 28S rDNA
# -  Production and transduction of adeno-associated viruses
# -  RGC sorting and RNA-seq
# -  ChIP-sequencing
# -  Hi-C
# -  HiChIP
# -  Whole-genome sequencing
# -  RRBS and epigenetic (DNA methylation) clock for fibroblasts
# -  Epigenetic (DNA methylation) clock for blood and muscle
# -  Histone mass spectrometry
# -  ChIP-seq aligning reads
# -  ChIP-seq visualizing read coverage
# -  ChIP-seq visualizing signal relative to background
# -  ChIP-seq peak Calling
#  TGFbeta signaling pathway
# - Epigenetic regulation
# - ATM and NBS1
# - Wnt signaling
# - Mitochondrial superoxide dismutase
# - DNA polymerase beta
# - CRISPR edits
# - macroH2A1
# - Telomere length
# - Genomic instability
# - SIRT1
# - Histone H4 lysine 16 acetylation
# - Endothelial NAD(+)-H2S signaling network
# - Protein synthesis
# - Transposable elements
# - IFN
#  H3K4 Trimethylation complex
# - Transgenerational epigenetic inheritance
# - Genome-wide methylation profiles
# - Cell type-specific enhancers
# - MYC
# - Polycomb repressive Complex 1
# - ChIP-seq
# - Nampt knockdown
# - CA1
# - SIR2/3/4 complex
# - Pseudocapillarization
# - Mitochondrial morphology
# - TreeFam
# - Burrows-Wheeler transform
# - SAMtools
# - Sequence Alignment/Map format
# - DNA double-strand break repair
# - Subread aligner
# - Long-range interactions
# - Automated, continuous monitoring
# - Digital arthritis index
#  Epigenetic information
# - DNA methylation
# - Histone post-translational modifications
# - DNA-dependent protein kinase
# - Telomeric silencing
# - DNA double-strand breaks
# - Mitochondrial superoxide
# - Stem cell competition
# - Cockayne Syndrome
# - MEC1-dependent redistribution
# - DNA mismatch repair
# - CTCF
# - SIRT1
# - Nuclear architecture
# - BEDTools
# - DeepTools2
# - Roadmap Epigenomics Consortium
#  DNA polymerases
# - Glomerular parietal epithelial cells
# - Cytochrome c oxidase/succinate dehydrogenase (COX/SDH) double-labeling histochemistry
# - HOXB7 homeodomain protein
# - Set2 histone methyltransferase
# - LINE1 Derepression
# - APOE stabilization
# - Transcriptional silencing
# - Extrachromosomal rDNA circles
# - Lamin B1 depletion
# - Nuclear reprogramming factors
# - H3K36 methylation
# - Werner’s Syndrome
# - Adipogenic traits
# - ATR gene
# - SIRT6-deficient mice
# - Polycomb repressive complex PRC1
# - TreeFam
# - Endogenous DNA double-strand breaks
# - ChIP-Enrich
# - UCSC Genome Browser
# - Multi-tissue DNA methylation age predictor
# - Skeletal muscle gene expression
# - Induction of pluripotent stem cells
# - Localized histone acetylation and deacetylation
# - SIRT6
# - Small nucleoli
#  Epigenetic information
# - Histone variants
# - DNA double-strand breaks
# - Pleiotropy
# - Transcription factors
# - Mediator
# - Super-enhancers
# - Transposable elements
# - Chromatin-modifying genetic interventions
# - Genomic organization
# - CTCF clustering
# - Cytosolic DNA sensors
# - Methylation
# - Wnt signaling
# - HMGB1
# - Podocyte repopulation
# - MyoD
# - HiCRep
# - Radioresistance
# - NLRC5/MHC class I transactivator
# - GAPDH
# - TUJ1
# - HA-Peroxidase
# - Oct3/4
# - Klf4
# - Anti-mouse IgG
# - Anti-rabbit IgG
# - Bacterial and virus strains
# - Camptothecin
# - Paraquat
# - Hydrogen peroxide
# - Phleomycin
# - dCTP [a-32P]
# - L-[35S]-Methionine
# - Recombinant I-PpoI
# - Rodent Chow Diet
# - LightCycler 480 SYBR Green I Master
# - Dynabeads Protein A for Immunoprecipitation
# - Dynabeads Protein G for Immunoprecipitation
# - Dynabeads M-280 Streptavidin
# - UltraPure Buffer-Saturated Phenol
# - Phenylalanine, L-[2,3,4,5,6-3H]
# - Hematoxylin solution modified acc.
#  Epigenetic information
# - Mammalian aging
# - Eosin Y-solution
# - bFGF
# - ISX9
# - Forskolin
# - CHIR99021
# - I-BET151
# - Fasudil
# - SB203580
# - Dynabeads Protein A and G
# - AMPure XP Beads
# - Propidium Iodide
# - Fetal Bovine Serum
# - Charcoal Stripped FBS
# - Tet System Approved FBS
# - N-2 Supplement
# - B-27 Supplement
# - GlutaMAX Supplement
# - Neurobasal Medium
# - 0.1% Gelatin
# - Formaldehyde
# - Paraformaldehyde
# - Adenosine-5’-triphosphate disodium salt hydrate
# - NEBNext High-Fidelity 2X PCR Master Mix
# - TRIzol Reagent
# - VECTASHIELD PLUS Antifade Mounting Medium
# - cOmplete EDTA-free Protease Inhibitor Cocktail
# - Phosphatase Inhibitor Cocktail 2 and 3
# - SuperScript III Reverse Transcriptase
# - E. Tissue DNA Kit
# - E. Total RNA Kit I
# - iScript cDNA Synthesis Kit
# - NEBNext ChIP-Seq Library Prep Master Mix
# - NEBNext Multiplex Oligos for Illumina
# - RNeasy MinElute Cleanup Kit
# - NEXTflex Rapid RNA Sequencing Kit
# - NEXTflex RNA-Seq Barcodes
# - Nextera DNA Library Prep Kit
# - Dovetail HiChIP MNase Kit
# - QuantiFluor dsDNA System
# - QuantiFluor RNA System
# - Library Quantification Kits
# - Kapa Biosystems
# - ChIP DNA Clean & Concentrator
# - Surveyor Mutation Detection Kits
# - ChIP DNA Clean & Concentrator
# - Click-iT EdU Alexa Fluor 488 Flow Cytometry Assay Kit
# - Senescence b-Galactosidase Staining
# - WT Mouse Embryonic Fibroblasts
# - I-PpoI Mouse Embryonic Fibroblasts
# - Cre Mouse Embryonic Fibroblasts
# - ICE Mouse Embryonic Fibroblasts
# - Cre Mouse Adult Fibroblasts
# - ICE Mouse Adult Fibroblasts
# - I-SceI Mouse Embry
#  Glucocorticoid Receptor (GR)
# -  Triamcinolone Acetonide (TA)
# -  Mouse Adult Fibroblast Cells
# -  Western Blot Analysis
# -  Southern Blotting
# -  Surveyor Assay
# -  Metabolic Labeling of MEFs
# -  Quantification of Protein Synthesis
# -  Quantification of DSBs
# -  Indirect Calorimetry
# -  MMQPCR
# -  Frailty Index Assessment
# -  Lens Opacity Scoring
# -  Magnetic Resonance Imaging
# -  Micro CT Scanning
# -  Quantification of Optic Nerve Axons
#  ImageJ software
# - Immunohistochemistry
# - KRT5
# - Alexa Fluor
# - DAPI
# - GFAP
# - Iba1
# - g-H2AX
# - Goat anti-GFP
# - Tris-HCl TE saturated phenol
# - 18S ribosomal
# - CytB
# - Contextual fear conditioning
# - Barnes maze test
# - BIO-G53
# - TSE system
# - TopScanLite
# - Grip strength test
# - Treadmill test
# - Lactate measurement
# - Specific-pathogen-free (SPF)
# - Instrumented individually ventilated cages (IVC)
# - Innowheel
# - Innodome
# - Bed-r’Nest
# - Foraging mix
#  Epigenetic information
# -  Mammalian aging
# -  Vium Digital Smart Houses
# -  Treadmill Gait Analysis
# -  COX and capillary density staining
# -  Electron microscopy
# -  Podocyte density p57 and PAS
# -  Glomerular Injury
# -  Parietal epithelial cell to mesenchymal transition
# -  5-Ethynyl-2’-deoxyuridine (EdU) staining
# -  Microscopy and imaging for kidney
# -  Immunocytochemistry
# -  Senescence-associated b-galactosidase (SA-b-Gal) assay
#  Epigenetic information
# -  Senescence
# -  Small molecule-driven neuronal reprogramming
# -  Quantitative real-time PCR
# -  Design of PCR primers
# -  Mutation frequency of 28S rDNA
# -  Production and transduction of adeno-associated viruses
# -  RGC sorting and RNA-seq
# -  ChIP-sequencing
# -  Musle ChIP
#  Epigenetic Information
# - Chromatin
# - Dynabeads Protein A/G
# - Hi-C
# - HiChIP
# - Whole-genome sequencing
# - RRBS
# - DNA methylation
# - Illumina HiSeq X10
# - Illumina HiSeq 2500
# - BWA mem
# - pairtools
# - Bioanalyzer
# - AMPure XP beads
# - NEBNext Ultra enzymes
# - streptavidin beads
# - PCR enrichment
# - MNase
# - RIPA
# - cooler cload
# - cooler zoomify
# - juicer tool
# - BGI
# - Quick-DNA Universal kit
# - E. Tissue DNA Kit
# - RNaseA
# - Genomic DNA Clean & Concentrator-10
# - TruSeq DNA Library Preparation Kit
# - Illumina-compatible adapters
# - phiX
# - SVA package
# - ComBat
# - Bismark
# - Thompson multi-tissue clock
# - DNA/RNA Shield
# - Quick-DNA Plus Kit
# - EZ DNA Methylation-Lightning
# - SWARM
#  Illumina basecalling software
# - Bismark
# - Elastic net algorithm
# - Histone mass spectrometry
# - Bowtie 2
# - BAM format
# - BedTools
# - Macs2
# - UCSC command line tool
# - BedGraphToBigWig
# - Genomic Regions Enrichment of Annotations Tool (GREAT)
# - ChIP-Enrich
# - BWA mem
# - Pairsamtools
#  Principal Component Analysis
# -  Burrows-Wheeler Alignment
# -  Sequence Alignment/Map tools
# -  Genome Analysis Toolkit
# -  HaplotypeCaller
# -  DESeq2
# -  Heatmap.2
# -  4-OHT
# -  Etoposide
# -  Phleomycin
# -  Lamin B1
# -  Lamin A/C
# -  Hydrogen Peroxide
# -  Camptothecin
# -  Surveyor Nuclease Assay
# -  Ligation-Mediated PCR
# -  Metabolic 35S-Labeling
# -  Monochrome Multiplex Quantitative PCR
# -  Dual Energy X-ray Absorptiometry
# -  Respiratory Exchange Rate
# -  IGF-1
# -  KIT
# -  KRT55
# -  DAPI
#  Two-tailed Student’s t test
# - Mitochondrial DNA copy number
# - Mitochondria number
# - Mitochondrial perimeter
# - Cytochrome oxidase (COX) staining
# - Quantification of RNA from repetitive DNA elements
# - Echocardiogram
# - Genes altered
# - Padj
# - I-PpoI cut sites
# - Clock CpG sites
# - Histone modifications
# - Spike-in normalization
# - ATAC signal
# - H3K27ac peaks
# - Hoxa genes
# - Epigenome roadmap
# - Super-enhancers (SEs)
# - Adeno-associated virus (AAV)
# - Oct4
# - Klf4
# - Dox treatment
# - Epigenetic age
# - GFP expression
# - H3K36me2
# CPU times: user 268 ms, sys: 32.8 ms, total: 301 ms
# Wall time: 2min 48s

# %% [markdown]
# ## Filter redundant concepts
# We might have extracted the same infos multiple times between multiple chunks, let's remove the doublons:
#
# - V1 (current) remove duplicate (identical lowercase)
# - V2: use fuzzywuzzy for scoring similar things higher than th and pick the bigger one accross the set
# - V3: use sentence embeddings and remove things with similarity at a similar th

# %%
concepts = []
for response in responses:
    concepts.extend([x.replace("-", "").strip() for x in response.split("\n")])
concepts_uniques = list(set([x.lower() for x in concepts]))
len(concepts_uniques)
# Out:
# 426

# %%
concepts_uniques
# Out:
# ['reduced representation bisulfite sequencing (rrbs)',
#  'forskolin',
#  'isx9',
#  'h3k56ac',
#  'contextual fear conditioning',
#  'h3k36me2',
#  'werner’s syndrome',
#  'chipenrich',
#  'sirt1',
#  'myosin light chain 4',
#  'nextflex rapid rna sequencing kit',
#  'genomewide methylation profiles',
#  'topologically associated domains (tads)',
#  'trishcl te saturated phenol',
#  'mitochondrial superoxide dismutase',
#  'juicer tool',
#  'parp1',
#  'ligationmediated pcr',
#  'lamin b1 depletion',
#  'transcription factors',
#  'transposable elements',
#  'ice mouse embryonic fibroblasts',
#  'ippoi',
#  'quantification of dsbs',
#  'elastic net algorithm',
#  'etoposide',
#  'endothelial nad(+)h2s signaling network',
#  'yamanaka factors',
#  'dovetail hichip mnase kit',
#  'podocyte density',
#  'wnt signaling',
#  'treefam',
#  'lifespan',
#  'deeptools2',
#  'western blot analysis',
#  'h3k4 trimethylation complex',
#  'mediator',
#  'atp',
#  'ccl2',
#  'cooler cload',
#  'quantitative realtime pcr',
#  'epigenome roadmap',
#  'dna doublestrand break repair',
#  'phenylalanine, l[2,3,4,5,63h]',
#  'ctcf',
#  'mitochondrial ribosomal protein l55',
#  'induced pluripotent stem cells (ipscs)',
#  'haplotypecaller',
#  'histone variants',
#  'dna sequence',
#  'antirabbit igg',
#  'rodent chow diet',
#  'sirt6',
#  'gh2ax',
#  'teneleven translocation enzymes (tets)',
#  'multitissue dna methylation age predictor',
#  'ice mouse adult fibroblasts',
#  'macroh2a1',
#  'gfap',
#  'dual energy xray absorptiometry',
#  'mammalian aging',
#  'h3k122ac',
#  'parietal epithelial cell to mesenchymal transition',
#  'l[35s]methionine',
#  'topscanlite',
#  'tamoxifen (tam)',
#  'nextflex rnaseq barcodes',
#  'polycomb repressive complex prc1',
#  'truseq dna library preparation kit',
#  'genome analysis toolkit',
#  'digital arthritis index',
#  'complete edtafree protease inhibitor cocktail',
#  'cellular exdifferentiation',
#  'bedr’nest',
#  'ifn',
#  'telomere length',
#  'sva package',
#  '4oht',
#  'hic',
#  'automated, continuous monitoring',
#  'adenoassociated virus',
#  'bedgraphtobigwig',
#  'class ii major histocompatibility complex',
#  'instrumented individually ventilated cages (ivc)',
#  'wnt and hox genes',
#  'ez dna methylationlightning',
#  'dna/rna shield',
#  'wholegenome sequencing',
#  'echocardiogram',
#  'silent information regulator complex (sir2/3/4)',
#  '5ethynyl2’deoxyuridine (edu) staining',
#  'iscei',
#  'mec1dependent redistribution',
#  'epigenetic clocks',
#  'lamin b1',
#  'immunohistochemistry',
#  'microglia',
#  'cox and capillary density staining',
#  'brain immunohistochemistry',
#  'dna doublestrand breaks',
#  'bfgf',
#  'information theory of aging',
#  'chipseq aligning reads',
#  'quickdna universal kit',
#  'heatmap.2',
#  'camptothecin',
#  'propidium iodide',
#  'quantitative realtime pcr for transcription of repetitive elements',
#  'rdna locus',
#  'line1 derepression',
#  'iscript cdna synthesis kit',
#  'mutation frequency of 28s rdna',
#  'hichip',
#  'bedtools',
#  'bismark',
#  'loxpstoploxp cassette',
#  'serine139phosphorylated h2ax (gh2ax)',
#  'dynabeads protein a for immunoprecipitation',
#  'charcoal stripped fbs',
#  'superscript iii reverse transcriptase',
#  'magnetic resonance imaging',
#  'production and transduction of adenoassociated viruses',
#  'nampt knockdown',
#  'nebnext highfidelity 2x pcr master mix',
#  'extrachromosomal rdna circles',
#  'micro ct scanning',
#  'indirect calorimetry',
#  'hdac1',
#  'paraformaldehyde',
#  'long interspersed nuclear element1 (line1)',
#  'mitochondrial dna copy number',
#  'topoisomerase ii inhibitor',
#  'set2 histone methyltransferase',
#  'clock cpg sites',
#  'design of pcr primers for repetitive elements',
#  'dna breaks',
#  'longrange interactions',
#  'surveyor nuclease assay',
#  'glucocorticoid receptor (gr)',
#  'cytosolic dna sensors',
#  'haperoxidase',
#  'immunocytochemistry',
#  'twotailed student’s t test',
#  'genes altered',
#  'electron microscopy',
#  'h3k27ac',
#  'fetal bovine serum',
#  'histone h4 lysine 16 acetylation',
#  'h3k27me3',
#  'homeobox (hox)',
#  'treadmill gait analysis',
#  'n2 supplement',
#  'mnase',
#  'dox treatment',
#  'quantification of subepidermal thickness',
#  'doublestranded dna breaks (dsbs)',
#  'trizol reagent',
#  'nebnext multiplex oligos for illumina',
#  'apoe stabilization',
#  'wholegenome sequencing (wgs)',
#  'transgenerational epigenetic inheritance',
#  'tgfbeta signaling pathway',
#  'mitochondria number',
#  'p57 and pas representative images',
#  'nebnext ultra enzymes',
#  'southern blotting',
#  'samtools',
#  'illuminacompatible adapters',
#  'fasudil',
#  'ca1',
#  'streptavidin beads',
#  'rrbs and epigenetic (dna methylation) clock for fibroblasts',
#  'mouse frailty index (fi)',
#  'transcriptional silencing',
#  'genomic dna clean & concentrator10',
#  'cell typespecific enhancers',
#  'senescence bgalactosidase staining',
#  'iba1',
#  'dna mismatch repair',
#  'kapa biosystems',
#  'h3k27ac peaks',
#  'ambulatory activity',
#  'podocyte repopulation',
#  'dilated cardiomyopathy',
#  'posttranslational modifications',
#  'combat',
#  'glutamax supplement',
#  'hicrep',
#  'base excision repair (ber)',
#  'ippoi mouse embryonic fibroblasts',
#  'histone posttranslational modifications',
#  'alexa fluor',
#  'kit/cd117positive melanocyte stem cells',
#  '0.1% gelatin',
#  'surveyor assay',
#  'ctcf clustering',
#  'igf1',
#  'atp and mtdna measurement',
#  'localized histone acetylation and deacetylation',
#  'b27 supplement',
#  'chromatin',
#  'pseudocapillarization',
#  'fear conditioning',
#  'dna sequencing (chipseq)',
#  'ucsc genome browser',
#  'innowheel',
#  'cre mouse embryonic fibroblasts',
#  'protein synthesis',
#  'foraging mix',
#  'burrowswheeler transform',
#  'chromatinmodifying genetic interventions',
#  'musle chip',
#  'bowtie 2',
#  'atacseq',
#  'illumina hiseq x10',
#  'hoxa genes',
#  'astrocytes',
#  'bioanalyzer',
#  'nfkb',
#  'design of pcr primers',
#  'glomerular parietal epithelial cells',
#  'nuclear architecture',
#  'cytochrome oxidase (cox)',
#  'chromatin contacts',
#  'estrogen receptor domain gene (ert2)',
#  'rneasy minelute cleanup kit',
#  'chromatin factors',
#  'roadmap epigenomics consortium',
#  'ucsc command line tool',
#  'myc',
#  'phleomycin',
#  'rdna instability',
#  'ligationmediated pcr (lmpcr)',
#  'vectashield plus antifade mounting medium',
#  'induction of pluripotent stem cells',
#  'thompson multitissue clock',
#  'pcr enrichment',
#  'phosphatase inhibitor cocktail 2 and 3',
#  'cooler zoomify',
#  'atm and nbs1',
#  'vium digital smart houses',
#  'sequence alignment/map tools',
#  'tse system',
#  'deseq2',
#  'sterility',
#  'rnasea',
#  'ibet151',
#  'quantification of rna from repetitive dna elements',
#  'dna methylation clock',
#  'superenhancers',
#  'dna methyltransferases (dnmts)',
#  'epigenetic regulation',
#  'radioresistance',
#  'nucleotide excision repair (ner)',
#  'metabolic labeling of mefs',
#  'contextual fear conditioning test',
#  'surveyor mutation detection kits',
#  'adipogenic traits',
#  'iscei mouse embry',
#  'histone mass spectrometry',
#  'bacterial and virus strains',
#  'dna damage',
#  'rdna',
#  'podocyte density p57 and pas',
#  'paraquat',
#  'nucleolar size',
#  'small moleculedriven neuronal reprogramming',
#  'promoterenhancer (pe) communication',
#  'oct3/4',
#  'triamcinolone acetonide (ta)',
#  'senescenceassociated betagalactosidase (sabgal)',
#  'genomic instability',
#  'krt55',
#  'quantifluor dsdna system',
#  'metabolic 35slabeling',
#  'quickdna plus kit',
#  'e. tissue dna kit',
#  'frailty index assessment',
#  'dynabeads protein g for immunoprecipitation',
#  'dapi',
#  'hichip contact loops',
#  'microscopy and imaging for kidney',
#  'mouse adult fibroblast cells',
#  'ippoi cut sites',
#  'respiratory exchange rate',
#  'cre recombinase gene (creert2)',
#  'bam format',
#  'treefam database',
#  'specificpathogenfree (spf)',
#  'dynabeads m280 streptavidin',
#  'waddington valleys',
#  'swarm',
#  'goat antigfp',
#  'chipseq peak calling',
#  'burrowswheeler alignment',
#  'innodome',
#  'spikein normalization',
#  'dna damage response',
#  'polycomb repressive complex 1',
#  'nuclear reprogramming factors',
#  'dna doublestrand breaks (dsbs)',
#  'phix',
#  'hmgb1',
#  'adenosine5’triphosphate disodium salt hydrate',
#  'dna polymerases',
#  'dynabeads protein a/g',
#  'recombinant ippoi',
#  'hic contact matrixes',
#  'sequence alignment/map format',
#  'endogenous dna doublestrand breaks',
#  'subread aligner',
#  'methylation',
#  'epigenetic information',
#  'superenhancers (ses)',
#  'glomerular injury',
#  'mitochondrial morphology',
#  'genomic regions enrichment of annotations tool (great)',
#  'epigenetic landscape',
#  'krt5',
#  'mmqpcr',
#  'nlrc5/mhc class i transactivator',
#  'rnaseq',
#  'library quantification kits',
#  'lens opacity scoring',
#  'chipseq visualizing signal relative to background',
#  'formaldehyde',
#  'rrbs',
#  'cytochrome c oxidase/succinate dehydrogenase (cox/sdh) doublelabeling histochemistry',
#  'small nucleoli',
#  'antimouse igg',
#  'clickit edu alexa fluor 488 flow cytometry assay kit',
#  'mitochondrial dna',
#  'lactate measurement',
#  'adenoassociated virus (aav)',
#  'ubiquitin promoter',
#  'cytb',
#  'atac signal',
#  'repetitive elements',
#  'epigenetic (dna methylation) clock for blood and muscle',
#  'chromatin immunoprecipitation',
#  'pairsamtools',
#  'skeletal muscle gene expression',
#  'chir99021',
#  'dynabeads protein a and g',
#  'bwa mem',
#  'chromatinmodifying proteins',
#  'treadmill test',
#  'sirt6deficient mice',
#  'lightcycler 480 sybr green i master',
#  'principal component analysis',
#  'chipseq visualizing read coverage',
#  'tuj1',
#  'chip dna clean & concentrator',
#  'h3k36 methylation',
#  'tet system approved fbs',
#  'epigenetic age',
#  'quantification of optic nerve axons',
#  'neurobasal medium',
#  'ccl20',
#  'quantifluor rna system',
#  'lamin a/c',
#  'dna repair',
#  'retinal ganglion cells',
#  'hematoxylin solution modified acc.',
#  'ampure xp beads',
#  'imagej software',
#  'epithelial to mesenchymal transition (emt)',
#  'cre mouse adult fibroblasts',
#  'epigenetic clock',
#  'eosin ysolution',
#  'dna methylation',
#  'dna demethylation',
#  'ultrapure buffersaturated phenol',
#  'padj',
#  'macs2',
#  'quantification of protein synthesis',
#  'chipseq',
#  'mitochondrial superoxide',
#  'antagonistic pleiotropy',
#  'atr gene',
#  'illumina hiseq 2500',
#  'telomeric silencing',
#  'histone levels',
#  'barnes maze test',
#  'gfp expression',
#  'retrotransposons',
#  'ripa',
#  'monochrome multiplex quantitative pcr',
#  'stem cell competition',
#  'genomic organization',
#  'gapdh',
#  'p53mediated cellular senescence',
#  'illumina basecalling software',
#  'klf4',
#  'cockayne syndrome',
#  'crispr edits',
#  'rgc sorting and rnaseq',
#  'hoxb7 homeodomain protein',
#  'e. total rna kit i',
#  'nextera dna library prep kit',
#  'wt mouse embryonic fibroblasts',
#  'kit',
#  'pleiotropy',
#  'dctp [a32p]',
#  'mitochondrial perimeter',
#  'biog53',
#  'nebnext chipseq library prep master mix',
#  'dna polymerase beta',
#  '18s ribosomal',
#  'histone modifications',
#  'intracisternal aparticle (iap)',
#  'pairtools',
#  'oct4',
#  'grip strength test',
#  'cytochrome oxidase (cox) staining',
#  'myod',
#  'interleukin6 (il6)',
#  'sir2/3/4 complex',
#  'senescenceassociated bgalactosidase (sabgal) assay',
#  'chipsequencing',
#  'senescenceassociated bgalactosidase (sabgal)',
#  'dnadependent protein kinase',
#  'senescence',
#  'bgi',
#  'hydrogen peroxide',
#  'sb203580']

# %% [markdown]
# ## GPT-3 to get the definitions for each terms

# %%
def get_prompt_anki(text):
    prompt = f"""Write the content of an Anki card (front/back)for this concept: `{text}`:"""
    return prompt

ankis = {}
for i, concept in tqdm(enumerate(concepts_uniques)):
    response = get_response_gpt(get_prompt_anki(concept)).strip()
    # ugly    
    print(response)
    if "\n\n" in response:
        front, back = response.split("\n\n")
    else: # only "\n"
        front, back = response.split("\n")
    ankis[front] = back
    
    
# %%time
# Out:
# 0it [00:00, ?it/s]
# Front: What is reduced representation bisulfite sequencing (rrbs)?
#
# Back: Reduced representation bisulfite sequencing (rrbs) is a method of DNA methylation analysis that uses a reduced representation of the genome to identify methylation patterns. It is a cost-effective and efficient way to analyze the methylation status of CpG sites in a genome. It is used to study epigenetic changes in a variety of organisms, including humans.
# Front: What is forskolin?
# Back: Forskolin is a natural compound found in the root of the Indian coleus plant. It has been used for centuries in traditional Ayurvedic medicine to treat a variety of ailments. It is now being studied for its potential to treat a variety of conditions, including asthma, glaucoma, and obesity. It has also been studied for its potential to increase testosterone levels and improve heart health.
# Front: What is ISX9?
# Back: ISX9 is a type of gene that is involved in the development of the nervous system. It is a transcription factor that helps regulate the expression of other genes involved in the formation of neurons and glia.
# Front: What is the abbreviation for the histone modification H3K56ac?
#
# Back: H3K56ac stands for Histone 3 Lysine 56 Acetylation.
# Front: What is contextual fear conditioning?
#
# Back: Contextual fear conditioning is a type of learning in which an animal learns to associate a particular context with an aversive stimulus. This type of learning is often used to study the neural basis of fear and anxiety. In a typical experiment, an animal is placed in a context and then exposed to an aversive stimulus, such as a mild electric shock. After repeated exposures, the animal will begin to show fear responses when placed in the context, even in the absence of the aversive stimulus.
# Front: What is h3k36me2?
#
# Back: h3k36me2 is a histone modification that is associated with active transcription. It is a trimethylation of lysine 36 on histone H3.
# Front: What is Werner's Syndrome?
#
# Back: Werner's Syndrome is a rare genetic disorder that causes premature aging. It is caused by a mutation in the WRN gene, which is responsible for the production of a protein that helps maintain the structure of chromosomes. Symptoms include graying and thinning of the hair, wrinkles, cataracts, and a decrease in the body's ability to fight off infections.
# Front: What is Chipenrich?
# Back: Chipenrich is a bioinformatics tool that uses gene expression data to identify enriched pathways and gene sets in a given sample. It is used to identify biological pathways and gene sets that are significantly enriched in a given sample compared to a reference dataset.
# Front: What is SIRT1?
# Back: SIRT1 is a protein that is involved in the regulation of metabolism, inflammation, and aging. It is a member of the sirtuin family of proteins, which are NAD+-dependent deacetylases. SIRT1 has been linked to a variety of health benefits, including increased longevity, improved metabolic health, and reduced inflammation.
# Front: What is myosin light chain 4?
#
# Back: Myosin light chain 4 (MLC4) is a protein found in the sarcomeres of skeletal muscle cells. It is part of the myosin complex, which is responsible for muscle contraction. MLC4 is the most abundant myosin light chain in skeletal muscle and is essential for normal muscle function.
# Front: What is the name of the rapid RNA sequencing kit developed by NextFlex?
#
# Back: The NextFlex Rapid RNA Sequencing Kit.
# Front: What are genomewide methylation profiles?
#
# Back: Genomewide methylation profiles are a type of epigenetic analysis that looks at the methylation status of all the genes in a genome. This type of analysis can be used to identify changes in gene expression and to study the effects of environmental factors on gene expression.
# Front: What are topologically associated domains (TADs)?
#
# Back: TADs are regions of the genome that are physically linked and interact with each other. They are thought to be important for gene regulation and are associated with the 3D structure of the genome.
# Front: What is trishcl te saturated phenol?
#
# Back: Trishcl te saturated phenol is a type of phenol that has been saturated with three chlorine atoms. It is used as an intermediate in the synthesis of pharmaceuticals and other organic compounds.
# Front: What is mitochondrial superoxide dismutase?
#
# Back: Mitochondrial superoxide dismutase (MnSOD) is an enzyme that helps to protect cells from oxidative damage by converting superoxide radicals into hydrogen peroxide and oxygen. It is found in the mitochondria of eukaryotic cells and is essential for maintaining cellular homeostasis.
# Front: What is a juicer tool?
#
# Back: A juicer tool is a kitchen appliance used to extract juice from fruits and vegetables. It typically consists of a motorized base, a strainer, and a container for collecting the juice.
# Front: What is the function of the protein Parp1?
#
# Back: Parp1 (Poly ADP-ribose polymerase 1) is a protein that helps repair DNA damage by activating enzymes that help repair single-stranded DNA breaks. It also plays a role in regulating gene expression and cell death.
# Front: What is ligation-mediated PCR?
#
# Back: Ligation-mediated PCR (LM-PCR) is a technique used to amplify DNA fragments that are too large to be amplified by conventional PCR. It involves the use of a DNA ligase to join two short oligonucleotides to the ends of the target DNA fragment, followed by PCR amplification of the ligated product. LM-PCR is often used to amplify large genomic regions, such as those containing gene regulatory elements.
# Front: What is lamin B1 depletion?
#
# Back: Lamin B1 depletion is a type of genetic mutation that affects the nuclear lamina, a structure that helps to maintain the shape of the nucleus. It is associated with a variety of diseases, including muscular dystrophy, cardiomyopathy, and premature aging.
# Front: What are transcription factors?
# Back: Transcription factors are proteins that bind to specific DNA sequences and regulate the expression of genes. They can either activate or repress the transcription of a gene, depending on the type of transcription factor and the context in which it is acting.
# Front: What are transposable elements?
#
# Back: Transposable elements are pieces of DNA that can move around within the genome. They are also known as "jumping genes" because they can jump from one location to another. Transposable elements can cause mutations and can be used to study gene regulation.
# Front: What are ice mouse embryonic fibroblasts?
#
# Back: Ice mouse embryonic fibroblasts are a type of cell derived from the embryos of a species of mouse known as the ice mouse. These cells are used in research to study the effects of cold temperatures on cell growth and development. They are also used to study the effects of various drugs and treatments on cell growth and development.
# Front:
# What is the Japanese word for "deeply"?
#
# Back:
# Ippoi (いっぽい)
# Front: What is the quantification of DSBs?
#
# Back: Double-strand breaks (DSBs) are a type of DNA damage that can be quantified by measuring the amount of DNA fragments that are generated when the DNA is broken. This can be done using techniques such as pulsed-field gel electrophoresis or Southern blotting.
# Front: What is the elastic net algorithm?
#
# Back: The elastic net algorithm is a regularization technique used in machine learning that combines the L1 and L2 regularization methods. It is used to reduce the complexity of a model and prevent overfitting. It works by adding a penalty term to the loss function that penalizes large weights and encourages the model to use a combination of all the features.
# Front: What is Etoposide?
# Back: Etoposide is a chemotherapy drug used to treat a variety of cancers, including testicular cancer, lung cancer, and lymphoma. It works by interfering with the growth of cancer cells and preventing them from dividing and spreading.
# Front: What is the endothelial NAD(+)H2S signaling network?
#
# Back: The endothelial NAD(+)H2S signaling network is a complex system of enzymes and proteins that regulate the production of hydrogen sulfide (H2S) in the endothelium, the innermost layer of cells that line the blood vessels. This network is important for maintaining vascular health and is involved in a variety of physiological processes, including vasodilation, angiogenesis, and inflammation.
# Front: What are Yamanaka Factors?
# Back: Yamanaka Factors are a set of four transcription factors (Oct4, Sox2, Klf4, and c-Myc) that can be used to reprogram adult cells into induced pluripotent stem cells (iPSCs). These iPSCs can then be used to generate any type of cell in the body.
# Front: What is a dovetail hichip mnase kit?
#
# Back: A dovetail hichip mnase kit is a tool used to create dovetail joints in woodworking. It consists of a hichip (a type of chisel) and a mnase (a type of saw) that are used together to create the dovetail joint.
# Front: What is podocyte density?
#
# Back: Podocyte density is a measure of the number of podocytes per unit area of the glomerular basement membrane. It is an important indicator of glomerular filtration rate and is used to diagnose and monitor kidney diseases.
# Front: What is Wnt signaling?
# Back: Wnt signaling is a pathway of cell-to-cell communication that plays a role in the development and maintenance of many tissues and organs. It is involved in a wide range of biological processes, including cell proliferation, differentiation, and migration. Wnt signaling is mediated by a family of proteins known as Wnt ligands, which bind to receptors on the cell surface and activate downstream signaling pathways.
# Front: What is TreeFam?
#
# Back: TreeFam is a database of evolutionary relationships between genes and proteins in animals, plants, fungi, and bacteria. It is a comprehensive resource for phylogenetic trees and associated data for animal, plant, fungal, and bacterial gene families.
# Front: What is the average lifespan of a human?
#
# Back: The average lifespan of a human is approximately 79 years.
# Front: What is deeptools2?
#
# Back: DeepTools2 is a suite of command-line tools for analyzing and visualizing deep sequencing data. It provides a range of tools for analyzing and visualizing data from high-throughput sequencing experiments, such as ChIP-seq, RNA-seq, and DNA-seq. DeepTools2 can be used to identify and visualize patterns in sequencing data, compare samples, and generate publication-quality figures.
# Front: What is Western Blot Analysis?
#
# Back: Western Blot Analysis is a laboratory technique used to detect and identify specific proteins in a sample. It involves separating proteins by size using gel electrophoresis, transferring them to a membrane, and then probing the membrane with antibodies specific to the target protein. The presence of the target protein is then detected using a chemiluminescent or fluorescent substrate.
# Front: What is the H3K4 trimethylation complex?
#
# Back: The H3K4 trimethylation complex is a protein complex that is responsible for the trimethylation of histone H3 lysine 4 (H3K4me3). This modification is associated with active gene expression and is important for the regulation of gene expression in eukaryotic cells.
# Front: What is a mediator?
# Back: A mediator is a neutral third party who helps two or more parties in a dispute reach a mutually acceptable agreement. Mediators use a variety of techniques to help the parties communicate effectively and reach a resolution.
# Front: What is ATP?
# Back: ATP stands for Adenosine Triphosphate, and is the primary energy currency of the cell. It is a nucleotide composed of adenine, ribose, and three phosphate groups. ATP is used to store and transfer energy within cells, and is essential for many cellular processes.
# Front: What is CCL2?
# Back: CCL2 is a chemokine also known as monocyte chemoattractant protein-1 (MCP-1). It is a small cytokine that belongs to the CC chemokine family and is involved in the recruitment of monocytes, memory T cells, and dendritic cells to sites of inflammation.
# Front: What is a cooler cloud?
#
# Back: A cooler cloud is a type of cloud formation that is composed of ice crystals and is usually found at higher altitudes. It is often seen in the form of cirrus clouds and is usually associated with fair weather.
# Front: What is quantitative realtime PCR?
#
# Back: Quantitative realtime PCR (qPCR) is a laboratory technique used to measure the amount of a specific DNA or RNA sequence in a sample. It is a highly sensitive and specific method that can detect even small amounts of nucleic acid. qPCR is used in a variety of applications, including gene expression analysis, pathogen detection, and genetic testing.
# Front: What is the Epigenome Roadmap?
#
# Back: The Epigenome Roadmap is an international research project that seeks to map the epigenetic modifications of the human genome. It is a collaborative effort between the National Institutes of Health (NIH) and the National Human Genome Research Institute (NHGRI). The project aims to identify and characterize the epigenetic modifications that occur in different tissues and cell types, and to understand how these modifications affect gene expression and other biological processes.
# Front: What is DNA double-strand break repair?
#
# Back: DNA double-strand break repair is a process in which cells repair broken DNA strands. It involves the recognition of the broken strands, the removal of the damaged DNA, and the rejoining of the two strands. This process is essential for maintaining the integrity of the genome and preventing mutations.
# Front: What is the chemical formula for phenylalanine?
# Back: C9H11NO2, l[2,3,4,5,63h]
# Front: What is CTCF?
# Back: CTCF (CCCTC-binding factor) is a transcription factor that binds to the CCCTC-motif in DNA and plays a role in regulating gene expression. It is involved in a variety of processes, including chromatin organization, transcriptional regulation, and DNA repair.
# Front: What is mitochondrial ribosomal protein L55?
#
# Back: Mitochondrial ribosomal protein L55 (MRPL55) is a protein that is part of the mitochondrial ribosome, which is responsible for the synthesis of proteins in the mitochondria. It is involved in the assembly of the mitochondrial ribosome and is essential for the proper functioning of the mitochondria.
# Front: What are induced pluripotent stem cells (iPSCs)?
#
# Back: iPSCs are adult cells that have been genetically reprogrammed to an embryonic stem cell-like state. They can be used to generate any type of cell in the body, making them a powerful tool for regenerative medicine and disease modeling.
# Front: What is haplotypecaller?
#
# Back: Haplotypecaller is a software tool used in bioinformatics to detect genetic variants from high-throughput sequencing data. It is part of the Genome Analysis Toolkit (GATK) developed by the Broad Institute. It uses a probabilistic model to call variants from aligned sequencing reads.
# Front: What are histone variants?
# Back: Histone variants are proteins that replace the core histones in chromatin, the material that packages and orders DNA in the nucleus of a cell. They are important for regulating gene expression and other cellular processes.
# Front: What is a DNA sequence?
# Back: A DNA sequence is a particular order of nucleotides within a DNA molecule. It is the basic unit of heredity and is responsible for the genetic instructions that determine the characteristics of every living organism.
# Front: What is antirabbit IgG?
# Back: Antirabbit IgG is an antibody that is used to detect the presence of rabbit antibodies in a sample. It is used in immunoassays to detect the presence of rabbit antibodies in a sample.
# Front: What is a rodent chow diet?
#
# Back: A rodent chow diet is a type of diet specifically designed for rodents, such as mice and rats. It typically consists of a combination of grains, seeds, nuts, and other ingredients that provide the necessary nutrients for a healthy rodent.
# Front: What is SIRT6?
# Back: SIRT6 is a protein that is involved in the regulation of metabolic processes, DNA repair, and gene expression. It is a member of the sirtuin family of proteins, which are known for their role in longevity and aging.
# Front: What is the chemical formula for glycolic acid?
# Back: The chemical formula for glycolic acid is GH2AX.
# Front: What are TETs?
# Back: TETs (teneleven translocation enzymes) are a family of enzymes that catalyze the oxidation of 5-methylcytosine to 5-hydroxymethylcytosine, a key step in DNA methylation and gene regulation.
# Front: What is a multitissue DNA methylation age predictor?
#
# Back: A multitissue DNA methylation age predictor is a tool used to estimate a person's biological age based on the levels of DNA methylation in multiple tissues. It is based on the observation that DNA methylation levels tend to increase with age, and can be used to estimate a person's age more accurately than chronological age.
# Front: What are ice mouse adult fibroblasts?
#
# Back: Ice mouse adult fibroblasts are a type of cell derived from the skin of a mouse that has been genetically modified to be resistant to cold temperatures. They are used in research to study the effects of cold on cell function and development.
# Front: What is macroh2a1?
# Back: Macroh2a1 is a gene that is responsible for the production of a protein called histone H2A.1, which is involved in the regulation of gene expression in eukaryotic cells.
# Front: What does GFAP stand for?
#
# Back: GFAP stands for Glial Fibrillary Acidic Protein, a type of intermediate filament protein found in astrocytes, a type of glial cell in the central nervous system.
# Front: What is Dual Energy X-Ray Absorptiometry?
#
# Back: Dual Energy X-Ray Absorptiometry (DEXA) is a medical imaging technique used to measure bone mineral density and body composition. It uses two X-ray beams with different energy levels to measure the amount of energy absorbed by different tissues in the body. DEXA is used to diagnose osteoporosis and other bone diseases, as well as to measure body fat and muscle mass.
# Front: What is mammalian aging?
#
# Back: Mammalian aging is the process of deterioration that occurs in mammals over time. It is characterized by a decrease in physical and mental abilities, as well as an increased risk of disease and death. Aging is a natural process that is affected by both genetic and environmental factors.
# Front: What is the histone modification h3k122ac?
#
# Back: h3k122ac is a histone modification that is associated with active transcription and is found in the promoter regions of genes.
# Front: What is parietal epithelial cell to mesenchymal transition?
#
# Back: Parietal epithelial cell to mesenchymal transition (PEMT) is a process in which parietal epithelial cells undergo a series of changes to become mesenchymal cells. This process is important for the development of organs and tissues, and is also involved in the formation of fibrosis and cancer metastasis.
# Front:
# What is l[35s]methionine?
#
# Back:
# l[35s]methionine is an amino acid that is essential for protein synthesis in humans. It is a sulfur-containing amino acid that is found in many proteins and is important for the proper functioning of the body.
# Front: What is Topscanlite?
# Back: Topscanlite is a free online tool that allows users to quickly scan documents and convert them into PDFs. It is easy to use and provides a fast and secure way to store documents.
# Front: What is tamoxifen (tam)?
# Back: Tamoxifen (tam) is a medication used to treat and prevent breast cancer. It works by blocking the effects of the hormone estrogen in the body. It is also used to reduce the risk of breast cancer in women at high risk of developing the disease.
# Front: What are NextFlex RNAseq barcodes?
#
# Back: NextFlex RNAseq barcodes are short DNA sequences used to identify and track samples during RNA sequencing. They are used to distinguish between samples and to ensure accurate data analysis.
# Front: What is Polycomb Repressive Complex PRC1?
#
# Back: Polycomb Repressive Complex PRC1 is a protein complex that is involved in epigenetic gene silencing. It is composed of several proteins, including Polycomb, Bmi1, Ring1A, and Ring1B, and is involved in the formation of repressive chromatin structures. PRC1 is important for maintaining the correct expression of genes during development and differentiation.
# Front: What is the name of the DNA library preparation kit used in TruSeq sequencing?
#
# Back: The TruSeq DNA Library Preparation Kit.
# Front: What is a genome analysis toolkit?
#
# Back: A genome analysis toolkit is a set of software tools used to analyze and interpret genomic data. It typically includes tools for sequence alignment, variant calling, gene expression analysis, and other bioinformatics tasks.
# Front: What is the Digital Arthritis Index?
#
# Back: The Digital Arthritis Index is a tool developed by the Arthritis Foundation to measure the impact of arthritis on a person's daily life. It uses a combination of self-reported surveys and digital health data to measure the severity of a person's arthritis symptoms and the impact of those symptoms on their daily activities.
# Front: What is a complete EDTA-free protease inhibitor cocktail?
#
# Back: A complete EDTA-free protease inhibitor cocktail is a mixture of protease inhibitors that are used to prevent proteolytic degradation of proteins during sample preparation. It typically contains a combination of inhibitors such as aprotinin, leupeptin, pepstatin, and EDTA-free PMSF.
# Front: What is cellular exdifferentiation?
#
# Back: Cellular exdifferentiation is the process by which a cell changes from one type to another, such as from a stem cell to a specialized cell type. It is an important part of development and regeneration in multicellular organisms.
# Front: What is a bedr'nest?
# Back: A bedr'nest is a type of bedding that is designed to provide a comfortable and supportive sleeping environment. It is made up of a mattress, a box spring, and a frame that is designed to fit together to create a snug and supportive sleeping surface. It is often used in dorm rooms and other small spaces where space is limited.
# Front: What does `ifn` stand for?
#
# Back: `ifn` stands for interferon. Interferons are proteins that are produced by cells in response to viral infections and other stimuli. They play an important role in the body's immune response by helping to regulate the activity of other immune cells.
# Front: What is telomere length?
#
# Back: Telomere length is the length of the protective caps at the end of chromosomes. Telomeres shorten with each cell division, and when they become too short, the cell can no longer divide and dies. Longer telomeres are associated with longer lifespan and better health.
# Front: What is an SVA package?
# Back: An SVA package is a software package that provides a set of tools and libraries for developing and deploying software applications. It includes a compiler, linker, debugger, and other tools for building and running applications. It also includes libraries for common tasks such as networking, graphics, and multimedia.
# Front: What does 4oht stand for?
# Back: 4oht stands for 4-hydroxy-3-methoxyphenethylamine, a naturally occurring trace amine found in the human body.
# Front: What does "hic" mean?
# Back: "Hic" is an interjection used to express surprise, excitement, or dismay.
# Front: What is automated, continuous monitoring?
#
# Back: Automated, continuous monitoring is a process of collecting data from a system or environment at regular intervals and analyzing it for any changes or anomalies. This type of monitoring can help detect problems early and provide insights into system performance.
# Front: What is an adenoassociated virus?
#
# Back: An adenoassociated virus (AAV) is a small, non-pathogenic virus that can be used to deliver genetic material into cells. It is commonly used in gene therapy and has been used to treat a variety of diseases, including hemophilia, cystic fibrosis, and Parkinson's disease.
# Front: What is the purpose of the bedgraphtobigwig command?
#
# Back: The bedgraphtobigwig command is used to convert a bedGraph file into a BigWig file, which is a compressed, indexed format for displaying dense, continuous data such as genome-wide coverage data.
# Front: What is a Class II Major Histocompatibility Complex?
#
# Back: A Class II Major Histocompatibility Complex (MHC) is a group of proteins found on the surface of cells that help the immune system recognize foreign substances. The MHC is divided into two classes, Class I and Class II, which are responsible for different functions. Class II MHC molecules are responsible for presenting antigens to T-cells, which then activate the immune response.
# Front: What are instrumented individually ventilated cages (IVC)?
#
# Back: Instrumented individually ventilated cages (IVC) are specialized cages used in laboratory animal research. They are designed to provide a controlled environment for the animals, with individually adjustable temperature, humidity, and ventilation. The cages are also equipped with sensors to monitor the animals' health and behavior.
# Front: What are Wnt and Hox genes?
#
# Back: Wnt and Hox genes are two families of transcription factors that play a role in the development of organisms. Wnt genes are involved in the regulation of cell fate and the formation of tissues and organs, while Hox genes are involved in the patterning of the body axis.
# Front: What is ez DNA methylation?
#
# Back: ez DNA methylation is a technique used to quickly and accurately measure the level of DNA methylation in a sample. It uses a combination of enzymatic digestion and high-throughput sequencing to provide a comprehensive view of the methylation status of a sample.
# Front: What is a DNA/RNA shield?
#
# Back: A DNA/RNA shield is a protective layer of proteins that surrounds the DNA and RNA molecules in a cell, helping to protect them from damage and keep them stable. It also helps to regulate the expression of genes and control the flow of genetic information.
# Front: What is whole genome sequencing?
#
# Back: Whole genome sequencing is a laboratory technique used to determine the complete DNA sequence of an organism's genome at a single time. It can be used to identify genetic variations, mutations, and other features of the genome. It is a powerful tool for understanding the genetic basis of health and disease.
# Front: What is an echocardiogram?
#
# Back: An echocardiogram is an ultrasound of the heart that uses sound waves to create a picture of the heart's structure and function. It is used to diagnose and monitor conditions such as heart valve disease, heart failure, and congenital heart defects.
# Front: What are the components of the Silent Information Regulator Complex?
#
# Back: The Silent Information Regulator Complex (SIR2/3/4) is a family of proteins that regulate gene expression in response to environmental cues. SIR2 is the founding member of the family and is responsible for the regulation of chromatin structure and gene silencing. SIR3 and SIR4 are additional members of the family that are involved in the regulation of gene expression and chromatin structure.
# Front: What is 5ethynyl2’deoxyuridine (edu) staining?
#
# Back: 5ethynyl2’deoxyuridine (edu) staining is a technique used to detect newly synthesized DNA strands in cells. It involves labeling newly synthesized DNA strands with a fluorescent dye, which can then be visualized under a microscope. This technique is useful for studying DNA replication and other cellular processes.
# Front: What is ISCEI?
# Back: ISCEI stands for the International Society for Computers and their Applications in Education and Industry. It is an international organization that promotes the use of computers and related technologies in education and industry.
# Front: What is mec1dependent redistribution?
# Back: Mec1dependent redistribution is a process in which proteins are redistributed from one cellular compartment to another. It is mediated by the Mec1 protein, which is a kinase that is involved in the regulation of cell cycle progression. Mec1dependent redistribution is important for the maintenance of cellular homeostasis and for the proper functioning of the cell.
# Front: What are epigenetic clocks?
#
# Back: Epigenetic clocks are a type of biomarker that measure biological age by analyzing changes in DNA methylation patterns. They are used to estimate the biological age of a person, which may differ from their chronological age.
# Front: What is lamin B1?
# Back: Lamin B1 is a type of nuclear lamina protein found in the inner nuclear membrane of eukaryotic cells. It is involved in the maintenance of nuclear structure and is essential for the proper functioning of the cell.
# Front: What is immunohistochemistry?
#
# Back: Immunohistochemistry (IHC) is a technique used to detect the presence of specific proteins in tissue samples. It involves using antibodies that are specific to the protein of interest, which are then labeled with a fluorescent dye or enzyme. The labeled antibodies are then applied to the tissue sample, and the presence of the protein is detected by the fluorescent dye or enzyme.
# Front: What are microglia?
# Back: Microglia are the primary immune cells of the central nervous system. They are responsible for detecting and responding to pathogens, damaged cells, and other foreign substances in the brain and spinal cord. They also play a role in the development and maintenance of the nervous system.
# Front: What is Cox and Capillary Density Staining?
#
# Back: Cox and Capillary Density Staining is a histological technique used to measure the number of capillaries in a tissue sample. It involves staining the tissue with a dye that binds to the endothelial cells of the capillaries, allowing them to be counted under a microscope. This technique is used to study the effects of various treatments on capillary density and can be used to diagnose certain diseases.
# Front: What is brain immunohistochemistry?
#
# Back: Brain immunohistochemistry is a technique used to detect the presence of specific proteins in brain tissue. It involves staining brain tissue with antibodies that bind to the target proteins, allowing them to be visualized under a microscope. This technique is used to diagnose and study neurological diseases, as well as to study the structure and function of the brain.
# Front: What are DNA double-strand breaks?
#
# Back: DNA double-strand breaks are physical breaks in both strands of the DNA double helix. They can be caused by exposure to radiation, chemicals, or other environmental factors, and can lead to mutations and other genetic changes.
# Front: What does BFGF stand for?
# Back: BFGF stands for Big Friendly Giant Friend.
# Front: What is the information theory of aging?
#
# Back: The information theory of aging is a theory that suggests that aging is caused by the accumulation of errors in the information stored in our cells. It proposes that aging is the result of the gradual accumulation of errors in the information stored in our cells, which leads to a decrease in the accuracy of the information and eventually to the death of the cell.
# Front: What is chipseq aligning reads?
#
# Back: ChIP-seq (Chromatin Immunoprecipitation Sequencing) is a technique used to identify the locations of DNA-binding proteins in the genome. It involves cross-linking DNA-binding proteins to DNA, immunoprecipitating the DNA-protein complexes, and then sequencing the DNA to identify the locations of the proteins. Aligning reads is the process of mapping the sequenced reads to a reference genome to identify the locations of the DNA-binding proteins.
# Front: What is the name of the DNA extraction kit that can be used with any sample type?
#
# Back: The QuickDNA Universal Kit.
# Front: What is a heatmap.2?
# Back: Heatmap.2 is a type of data visualization that uses color to represent data values. It is used to quickly identify patterns and trends in large datasets. Heatmap.2 is often used to visualize correlations between variables, or to identify outliers in a dataset.
# Front: What is camptothecin?
# Back: Camptothecin is a natural product found in the bark of the North American tree Camptotheca acuminata. It is used in chemotherapy to treat certain types of cancer.
# Front: What is propidium iodide?
#
# Back: Propidium iodide is a fluorescent dye used in flow cytometry to detect DNA content in cells. It is a red-orange dye that binds to the DNA of dead cells, allowing them to be distinguished from live cells.
# Front: What is quantitative realtime PCR used for?
#
# Back: Quantitative realtime PCR is used to measure the transcription of repetitive elements in a sample. It is a powerful tool for measuring gene expression levels and can be used to detect changes in gene expression over time.
# Front: What is an rDNA locus?
#
# Back: An rDNA locus is a specific region of DNA that contains the genes responsible for ribosomal RNA (rRNA) production. It is composed of multiple copies of the same gene, which are transcribed and processed to form the mature rRNA molecules. The rDNA locus is essential for protein synthesis and is found in the nucleus of eukaryotic cells.
# Front: What is line1 derepression?
# Back: Line1 derepression is a process used to reduce the expression of a gene by introducing a mutation into the promoter region of the gene. This process is used to study the role of a gene in a particular biological process.
# Front: What is an iscript cdna synthesis kit?
#
# Back: An iscript cdna synthesis kit is a kit used to synthesize cDNA from mRNA. It includes a reverse transcriptase enzyme, oligo dT primers, and other components necessary for cDNA synthesis.
# Front: What is the mutation frequency of 28s rdna?
#
# Back: The mutation frequency of 28s rdna is estimated to be approximately 1.2 x 10-9 per site per year.
# Front: What is hichip?
# Back: Hichip is a type of chip used in electronic devices that is designed to be highly integrated and efficient. It combines multiple components into a single chip, allowing for smaller, more powerful devices.
# Front: What is bedtools?
# Back: bedtools is a suite of command-line tools for working with genomic features such as intervals, alignments, and sequence data. It can be used to intersect, merge, count, complement, and shuffle genomic intervals from multiple files in widely-used genomic file formats such as BAM, BED, GFF/GTF, VCF.
# Front: What is the name of the German chancellor who unified Germany in 1871?
#
# Back: Otto von Bismarck
# Front: What is a loxpstoploxp cassette?
#
# Back: A loxpstoploxp cassette is a type of genetic engineering tool used to create a double-stranded break in a gene. It consists of two loxP sites flanking a gene of interest, which can be removed by the Cre recombinase enzyme. This technique is used to create gene knockouts in order to study gene function.
# Front: What is serine139phosphorylated h2ax (γH2AX)?
#
# Back: γH2AX is a modified form of the histone H2AX that is phosphorylated at serine 139. It is a marker of DNA double-strand breaks and is used to measure the extent of DNA damage in cells.
# Front: What are Dynabeads Protein A used for?
#
# Back: Dynabeads Protein A are used for immunoprecipitation, a technique used to isolate and purify proteins from a sample. The beads are coated with Protein A, which binds to the Fc region of antibodies, allowing for the capture and purification of the target protein.
# Front: What is charcoal stripped FBS?
# Back: Charcoal stripped FBS (fetal bovine serum) is a type of serum that has been treated with activated charcoal to remove certain proteins, hormones, and other molecules. It is used in cell culture and other laboratory applications.
# Front: What is superscript iii reverse transcriptase?
#
# Back: Superscript iii reverse transcriptase is an enzyme used in molecular biology to reverse transcribe single-stranded RNA into double-stranded DNA. It is commonly used in the laboratory to create cDNA libraries for gene expression studies.
# Front: What is Magnetic Resonance Imaging (MRI)?
#
# Back: Magnetic Resonance Imaging (MRI) is a medical imaging technique used to create detailed images of the body's internal structures. It uses a powerful magnetic field, radio waves, and a computer to create detailed images of organs, soft tissues, bone, and other internal structures. MRI is often used to diagnose and monitor a variety of medical conditions.
# Front: What is the process of production and transduction of adenoassociated viruses?
#
# Back: Adenoassociated viruses (AAVs) are produced by co-transfecting a plasmid containing the AAV genome with a helper plasmid containing the necessary viral genes. The transduction process involves the introduction of the AAV genome into a host cell, where it is transcribed and translated into viral proteins. The viral proteins then assemble into a virus particle, which is released from the cell and can infect other cells.
# Front: What is a NAMPT knockdown?
#
# Back: A NAMPT knockdown is a technique used to reduce the expression of the NAMPT gene, which is involved in the regulation of energy metabolism. This technique is used to study the effects of reduced NAMPT expression on cellular processes such as cell growth, differentiation, and metabolism.
# Front: What is NebNext HighFidelity 2x PCR Master Mix?
#
# Back: NebNext HighFidelity 2x PCR Master Mix is a ready-to-use PCR master mix that contains a blend of Taq DNA polymerase, dNTPs, MgCl2, and reaction buffers optimized for high-fidelity PCR. It is designed to amplify DNA fragments up to 5 kb in length with high accuracy and reproducibility.
# Front: What are extrachromosomal rdna circles?
#
# Back: Extrachromosomal rdna circles (ERCs) are circular DNA molecules that are not part of the main chromosome. They are found in bacteria and are involved in the regulation of gene expression. ERCs can be used to transfer genetic material between cells and can also be used to study gene regulation.
# Front: What is Micro CT Scanning?
#
# Back: Micro CT scanning is a type of imaging technology that uses X-rays to create detailed 3D images of small objects. It is used to examine the internal structure of objects such as bones, teeth, and other small objects. It is also used to measure the density of materials and to detect defects in materials.
# Front: What is indirect calorimetry?
#
# Back: Indirect calorimetry is a method of measuring the energy expenditure of an individual by measuring the amount of oxygen consumed and carbon dioxide produced. It is used to measure the metabolic rate of an individual and can be used to assess the effectiveness of a diet or exercise program.
# Front: What is HDAC1?
# Back: HDAC1 (histone deacetylase 1) is an enzyme that removes acetyl groups from histones, which can lead to the condensation of chromatin and the repression of gene expression.
# Front: What is paraformaldehyde?
# Back: Paraformaldehyde is a white, odorless, crystalline solid that is used as a preservative and disinfectant. It is a polymer of formaldehyde, and is often used in the production of resins and plastics.
# Front: What is a Long Interspersed Nuclear Element (LINE1)?
#
# Back: LINE1 is a type of mobile genetic element that is found in the genomes of many eukaryotic organisms. It is composed of two open reading frames (ORFs) and is capable of replicating and transposing itself within the genome. LINE1 is responsible for a significant portion of the human genome, making up 17% of the total DNA.
# Front: What is mitochondrial DNA copy number?
#
# Back: Mitochondrial DNA copy number is the number of copies of mitochondrial DNA present in a cell. It is important for energy production and is regulated by the cell to ensure optimal energy production. Abnormalities in mitochondrial DNA copy number can lead to a variety of diseases.
# Front: What is a topoisomerase II inhibitor?
#
# Back: A topoisomerase II inhibitor is a type of drug that interferes with the activity of an enzyme called topoisomerase II, which is involved in DNA replication and repair. These drugs are used to treat certain types of cancer, as they can prevent the cancer cells from replicating and spreading.
# Front: What is a set2 histone methyltransferase?
#
# Back: A set2 histone methyltransferase is an enzyme that adds a methyl group to the lysine residue of histone proteins, which is a key step in the regulation of gene expression. This enzyme is involved in the formation of heterochromatin, which is a tightly packed form of DNA that is associated with gene silencing.
# Front: What are clock cpg sites?
#
# Back: Clock CPG sites are CpG sites that are located in the promoter regions of clock genes. These sites are important for the regulation of circadian rhythms and are thought to be involved in the regulation of gene expression.
# Front: What is the design of PCR primers for repetitive elements?
#
# Back: PCR primers for repetitive elements must be designed carefully to ensure that the primers are specific to the target sequence and do not amplify other sequences in the genome. Primers should be designed to have a high melting temperature, low self-complementarity, and a low GC content. Additionally, the primers should be designed to have a high specificity for the target sequence, and should be checked for secondary structure formation.
# Front: What are DNA breaks?
# Back: DNA breaks are physical disruptions in the DNA molecule, which can be caused by environmental factors such as radiation or chemicals, or by errors during DNA replication. DNA breaks can lead to mutations, which can have a variety of effects on the organism.
# Front: What are longrange interactions?
#
# Back: Longrange interactions are interactions between two or more organisms that occur over a large distance. Examples of longrange interactions include migration, pollination, and seed dispersal.
# Front: What is a surveyor nuclease assay?
#
# Back: A surveyor nuclease assay is a laboratory technique used to detect and measure the presence of specific DNA sequences. It involves using a restriction enzyme to cleave a DNA sample at a specific site, followed by a gel electrophoresis to separate the fragments. The results of the assay can be used to identify and quantify the presence of a particular DNA sequence.
# Front: What is the glucocorticoid receptor (GR)?
#
# Back: The glucocorticoid receptor (GR) is a type of nuclear receptor that binds to glucocorticoid hormones, such as cortisol, and regulates gene expression in response to stress. It is involved in a wide range of physiological processes, including metabolism, immune response, and development.
# Front: What are cytosolic DNA sensors?
#
# Back: Cytosolic DNA sensors are proteins that detect the presence of foreign DNA in the cytoplasm of a cell. They are involved in the innate immune response and can trigger the production of inflammatory cytokines and other molecules to protect the cell from infection.
# Front: What is the enzyme haperoxidase?
#
# Back: Haperoxidase is an enzyme that catalyzes the oxidation of phenols and other aromatic compounds. It is found in plants, fungi, and bacteria, and is involved in the breakdown of lignin and other plant cell wall components.
# Front: What is immunocytochemistry?
#
# Back: Immunocytochemistry is a technique used to detect the presence of specific proteins in cells. It involves labeling the proteins with antibodies that are linked to a fluorescent dye or enzyme, which can then be visualized under a microscope. This technique is used to study the localization and expression of proteins in cells, and can be used to diagnose diseases.
# Front: What is a two-tailed student's t test?
#
# Back: A two-tailed student's t test is a statistical test used to compare the means of two samples. It is used to determine if there is a statistically significant difference between the two samples. It is also known as a two-sample t-test.
# Front: What are genes altered?
# Back: Genes altered refers to changes in the DNA sequence of a gene, which can result in changes in the protein produced by the gene. These changes can be caused by mutations, which can be inherited or acquired, or by epigenetic modifications, which are changes in gene expression without changes in the DNA sequence.
# Front: What is electron microscopy?
#
# Back: Electron microscopy is a type of microscopy that uses a beam of accelerated electrons to generate a magnified image of a sample. It can be used to observe objects at a much higher resolution than is possible with a light microscope.
# Front: What is h3k27ac?
# Back: h3k27ac is a histone modification that is associated with gene activation. It is a mark of active chromatin and is found at the promoter regions of active genes.
# Front: What is fetal bovine serum?
#
# Back: Fetal bovine serum is a type of serum derived from the blood of unborn calves. It is used in cell culture media to provide essential nutrients for cell growth and is also used in research and medical applications.
# Front: What is histone H4 lysine 16 acetylation?
#
# Back: Histone H4 lysine 16 acetylation is a post-translational modification of the histone H4 protein, which is involved in the regulation of gene expression. It is a process in which an acetyl group is added to the lysine 16 residue of the histone H4 protein, resulting in a more relaxed chromatin structure and increased gene expression.
# Front: What is h3k27me3?
#
# Back: h3k27me3 is a histone modification that is associated with gene silencing. It is a trimethylation of lysine 27 on histone H3.
# Front: What is a homeobox (hox)?
#
# Back: A homeobox (hox) is a DNA sequence found in many organisms that is involved in the regulation of gene expression during development. It is a conserved sequence of 180-200 base pairs that is found in the regulatory regions of many genes. Hox genes are important for the development of body plans and the formation of body parts.
# Front: What is treadmill gait analysis?
#
# Back: Treadmill gait analysis is a type of biomechanical assessment used to evaluate the way a person walks or runs on a treadmill. It involves the use of specialized equipment to measure and analyze the body's movement, including joint angles, muscle activity, and force production. The results of the analysis can be used to identify potential areas of improvement and to develop an individualized treatment plan.
# Front: What is an N2 supplement?
#
# Back: An N2 supplement is a dietary supplement that contains nitrogen, which is an essential nutrient for the body. It is often used to help improve muscle growth and recovery, as well as to support overall health and well-being.
# Front: What is Mnase?
# Back: Mnase (micrococcal nuclease) is an enzyme that cleaves DNA at specific sites, allowing for the study of chromatin structure and gene expression. It is commonly used in biochemical and molecular biology experiments.
# Front: What is dox treatment?
#
# Back: Dox treatment is a type of chemotherapy that uses the drug doxorubicin to treat cancer. It is used to kill cancer cells and shrink tumors. It is often used in combination with other treatments such as radiation therapy and surgery.
# Front: What is the quantification of subepidermal thickness?
#
# Back: Subepidermal thickness is the distance between the epidermis and the dermis, and it can be quantified using a variety of techniques, such as ultrasound, optical coherence tomography, and confocal microscopy. These techniques measure the thickness of the subepidermal layer and can be used to diagnose and monitor skin conditions.
# Front: What are doublestranded DNA breaks (DSBs)?
#
# Back: Doublestranded DNA breaks (DSBs) are breaks in both strands of the DNA double helix. They can be caused by physical or chemical damage, and can lead to mutations and other genetic changes. Repair of DSBs is essential for maintaining the integrity of the genome.
# Front: What is Trizol reagent?
#
# Back: Trizol reagent is a solution used to extract nucleic acids from cells and tissues. It is composed of guanidine isothiocyanate, phenol, and a chaotropic salt. It is commonly used in molecular biology for the isolation of RNA, DNA, and proteins.
# Front: What is NebNext Multiplex Oligos for Illumina?
#
# ...
# Front: What is quantification of protein synthesis?
#
# Back: Quantification of protein synthesis is the process of measuring the amount of protein produced by a cell or organism. It is typically done by measuring the amount of mRNA or protein present in a sample. Quantification of protein synthesis can be used to study the regulation of gene expression, as well as to measure the effects of drugs or other treatments on protein production.
# Front: What is ChIP-seq?
#
# Back: ChIP-seq (Chromatin Immunoprecipitation Sequencing) is a technique used to identify the binding sites of DNA-associated proteins. It combines chromatin immunoprecipitation (ChIP) with massively parallel DNA sequencing to identify the binding sites of DNA-associated proteins, such as transcription factors, histones, and other chromatin-associated proteins.
# Front: What is mitochondrial superoxide?
# Back: Mitochondrial superoxide is a type of reactive oxygen species (ROS) that is produced as a byproduct of the electron transport chain in mitochondria. It is a highly reactive molecule that can damage cells and lead to oxidative stress.
# Front: What is antagonistic pleiotropy?
#
# Back: Antagonistic pleiotropy is a phenomenon in which a gene has two or more effects on an organism, one of which is beneficial and the other is detrimental. This can occur when a gene confers a benefit early in life, but has a negative effect later in life.
# Front: What is the ATR gene?
#
# Back: The ATR gene is a gene that encodes the ataxia-telangiectasia and Rad3-related protein, which is involved in the DNA damage response pathway. It is important for maintaining genomic stability and preventing cancer. Mutations in the ATR gene can lead to ataxia-telangiectasia, a rare genetic disorder characterized by progressive difficulty with movement and coordination.
# Front: What is the name of the sequencing platform used in Illumina sequencing?
#
# Back: The sequencing platform used in Illumina sequencing is the HiSeq 2500.
# Front: What is telomeric silencing?
#
# Back: Telomeric silencing is a form of epigenetic regulation in which the ends of chromosomes, known as telomeres, are silenced in order to prevent the expression of certain genes. This silencing is thought to be important for maintaining the stability of the genome and preventing the expression of potentially harmful genes.
# Front: What are histone levels?
#
# Back: Histone levels refer to the amount of histone proteins present in a cell. Histones are proteins that help package and organize DNA into structures called chromatin, which are essential for gene expression. Changes in histone levels can affect gene expression and can be used to regulate gene expression in response to environmental cues.
# Front: What is the Barnes Maze Test?
#
# Back: The Barnes Maze Test is a behavioral test used to measure spatial learning and memory in rodents. It consists of a circular platform with a number of holes around the edge, and a visible escape box in one of the holes. The animal is placed in the center of the platform and must find the escape box in order to be rewarded with food. The test is used to measure the animal's ability to learn and remember the location of the escape box.
# Front: What is GFP expression?
#
# Back: GFP expression is the process of introducing the gene for green fluorescent protein (GFP) into a cell or organism, allowing the protein to be expressed and visualized. GFP expression is commonly used in molecular biology and biotechnology to study gene expression and protein localization.
# Front: What are retrotransposons?
# Back: Retrotransposons are mobile genetic elements that replicate by copying and pasting themselves into new locations in the genome. They are composed of two parts: a long terminal repeat (LTR) and a coding region. Retrotransposons are thought to be responsible for a large portion of the genetic variation found in eukaryotes.
# Front: What is Ripa?
# Back: Ripa is a Buddhist term meaning "peaceful abiding". It is a practice of meditation and contemplation that is used to cultivate inner peace and insight.
# Front: What is Monochrome Multiplex Quantitative PCR?
#
# Back: Monochrome Multiplex Quantitative PCR (MMQ-PCR) is a technique used to detect and quantify multiple targets in a single reaction. It uses a single fluorescent dye to label all of the targets, allowing for simultaneous detection and quantification of multiple targets in a single reaction. This technique is useful for applications such as gene expression profiling, pathogen detection, and genetic variation analysis.
# Front: What is stem cell competition?
# Back: Stem cell competition is a process in which stem cells compete with each other for resources in order to survive and proliferate. This competition is thought to be an important factor in the development and maintenance of tissue homeostasis.
# Front: What is genomic organization?
#
# Back: Genomic organization is the structure of a genome, which includes the arrangement of genes and other elements within the genome. It is important for understanding how genes are regulated and how they interact with each other. Genomic organization can be studied at the level of DNA, RNA, and proteins.
# Front: What is Gapdh?
# Back: Gapdh stands for glyceraldehyde-3-phosphate dehydrogenase, an enzyme that catalyzes the sixth step of glycolysis. It is also used as a housekeeping gene in molecular biology experiments.
# Front: What is p53-mediated cellular senescence?
#
# Back: p53-mediated cellular senescence is a process in which cells become permanently arrested in the G1 phase of the cell cycle due to the activation of the tumor suppressor gene p53. This process is thought to be an important mechanism for preventing the proliferation of damaged or potentially cancerous cells.
# Front: What is Illumina basecalling software?
#
# Back: Illumina basecalling software is a computer program used to convert raw sequencing data from an Illumina sequencing machine into a readable format. It is used to identify the nucleotide bases in a DNA sequence and to generate a sequence file that can be used for further analysis.
# Front: What is the abbreviation for Kruppel-like factor 4?
#
# Back: KLF4
# Front: What is Cockayne Syndrome?
#
# Back: Cockayne Syndrome is a rare genetic disorder that affects the growth and development of the body. It is characterized by growth failure, premature aging, and sensitivity to sunlight. It is caused by mutations in the ERCC8 or CSA genes. Symptoms may include failure to thrive, developmental delays, hearing loss, vision problems, and skin abnormalities.
# Front: What is Crispr?
# Back: Crispr (Clustered Regularly Interspaced Short Palindromic Repeats) is a gene-editing technology that allows scientists to make precise edits to the DNA of living organisms. It works by using an enzyme to cut the DNA at a specific location, allowing scientists to insert, delete, or replace a gene.
# Front: What is RGC sorting and RNAseq?
#
# Back: RGC sorting is a method of sorting cells based on their expression of a particular gene or genes. RNAseq is a technique used to measure the expression of all genes in a sample. Together, these two techniques can be used to identify and quantify gene expression in a sample.
# Front: What is a hoxb7 homeodomain protein?
#
# Back: A hoxb7 homeodomain protein is a transcription factor that binds to DNA and regulates gene expression. It is a member of the homeobox family of proteins, which are involved in the development of organisms.
# Front: What is an e. total RNA kit?
#
# Back: An e. total RNA kit is a laboratory tool used to extract and purify total RNA from a sample. It typically includes reagents, buffers, and other components necessary for the extraction process. The kit is designed to provide high-quality, intact RNA for downstream applications such as RT-PCR, qPCR, and NGS.
# Front: What is the Nextera DNA Library Prep Kit?
#
# Back: The Nextera DNA Library Prep Kit is a kit used to prepare DNA libraries for next-generation sequencing. It includes reagents and protocols for sample preparation, library construction, and quality control. The kit is designed to enable rapid, cost-effective, and high-throughput library preparation for a variety of sample types.
# Front: What are mouse embryonic fibroblasts?
#
# Back: Mouse embryonic fibroblasts (MEFs) are cells derived from the inner cell mass of a mouse embryo. They are commonly used in cell culture and are a valuable tool for studying cell biology, gene expression, and developmental biology.
# Front: What is a kit?
# Back: A kit is a set of items, usually related to a specific activity, that is packaged together for convenience. Kits can include tools, supplies, instructions, and other items necessary for a particular task.
# Front: What is pleiotropy?
# Back: Pleiotropy is a phenomenon in which a single gene has multiple effects on the phenotype of an organism. This means that a single gene can influence multiple traits or characteristics.
# Front: What does the abbreviation "dctp [a32p]" stand for?
#
# Back: dctp [a32p] stands for deoxycytidine triphosphate (dCTP) and adenosine triphosphate (aTP).
# Front: What is the mitochondrial perimeter?
#
# Back: The mitochondrial perimeter is the outer boundary of the mitochondria, which is composed of two lipid bilayers. The inner membrane is the inner boundary of the mitochondria and is composed of proteins and lipids. The outer membrane is the outer boundary of the mitochondria and is composed of proteins and lipids.
# Front: What is Biog53?
# Back: Biog53 is a course at UC Berkeley that covers the principles of molecular biology and genetics. It focuses on the structure and function of genes, the regulation of gene expression, and the principles of inheritance.
# Front: What is NebNext ChipSeq Library Prep Master Mix?
#
# Back: NebNext ChipSeq Library Prep Master Mix is a reagent kit used to prepare libraries for ChIP-Seq experiments. It contains all the necessary components for library preparation, including enzymes, buffers, and adapters. The kit is designed to provide high-quality libraries with minimal hands-on time.
# Front: What is DNA polymerase beta?
#
# Back: DNA polymerase beta is an enzyme that is involved in DNA replication and repair. It is responsible for the accurate copying of DNA strands during replication and for the repair of damaged DNA strands.
# Front: What is 18s ribosomal?
# Back: 18s ribosomal is a type of ribosomal RNA (rRNA) found in eukaryotic cells. It is a component of the small subunit of the ribosome and is responsible for decoding mRNA during protein synthesis.
# Front: What are histone modifications?
#
# Back: Histone modifications are chemical changes to the proteins around which DNA is wrapped. These modifications can affect gene expression and can be used to regulate the activity of genes. Examples of histone modifications include acetylation, methylation, and phosphorylation.
# Front: What is an intracisternal aparticle (IAP)?
#
# Back: An intracisternal aparticle (IAP) is a type of retrovirus that is found in the cytoplasm of cells. It is composed of a single-stranded RNA genome surrounded by a protein capsid. IAPs are believed to be involved in the regulation of gene expression and can be used as a tool for gene therapy.
# Front: What are pairtools?
# Back: Pairtools are a set of tools used to facilitate pair programming. They provide features such as shared editing, shared debugging, and shared testing. Pairtools also provide a way for two developers to collaborate on a project without having to be in the same physical location.
# Front: What is the gene name for the transcription factor that plays a role in embryonic stem cell pluripotency?
#
# Back: Oct4 (POU5F1)
# Front: What is a grip strength test?
#
# Back: A grip strength test is a physical test used to measure the strength of a person's grip. It is often used to assess the strength of the hands and forearms, and is commonly used in physical therapy and occupational therapy. The test involves squeezing a hand-held dynamometer, which measures the amount of force applied to it.
# Front: What is cytochrome oxidase (cox) staining?
#
# Back: Cytochrome oxidase (cox) staining is a histological technique used to identify and visualize mitochondria in tissue sections. It is based on the principle that cytochrome oxidase, an enzyme found in the inner mitochondrial membrane, is highly reactive to certain dyes. The dye binds to the enzyme, resulting in a dark brown or black reaction product that can be seen under the microscope.
# Front: What is myod?
# Back: Myod is a transcription factor that is involved in the differentiation of skeletal muscle cells. It is a member of the MyoD family of transcription factors and is essential for the formation of skeletal muscle.
# Front: What is interleukin6 (IL6)?
# Back: Interleukin6 (IL6) is a cytokine that plays an important role in inflammation and immune response. It is produced by a variety of cells, including T cells, B cells, macrophages, and endothelial cells. IL6 is involved in a wide range of physiological processes, including wound healing, inflammation, and the development of autoimmune diseases.
# Front: What is the Sir2/3/4 complex?
#
# Back: The Sir2/3/4 complex is a group of proteins that are involved in the regulation of gene expression in yeast. It is composed of the Sir2, Sir3, and Sir4 proteins, which interact with each other to form a complex that binds to specific DNA sequences and modulates the expression of genes.
# Front: What is the senescence-associated beta-galactosidase (SABGAL) assay?
#
# Back: The SABGAL assay is a method used to measure the level of senescence in cells. It is based on the activity of the enzyme beta-galactosidase, which is produced by senescent cells. The assay involves staining cells with a fluorescent substrate and measuring the amount of fluorescence produced, which is proportional to the amount of beta-galactosidase present. This method is used to measure the level of senescence in cells and can be used to monitor the effects of aging on cells.
# Front: What is chipsequencing?
# Back: Chipsequencing is a type of DNA sequencing technology that uses a microarray chip to sequence DNA fragments. It is a high-throughput method that can sequence millions of DNA fragments in a single run. It is used in a variety of applications, including genotyping, gene expression analysis, and whole genome sequencing.
# Front: What is senescence-associated beta-galactosidase (SABGAL)?
#
# Back: Senescence-associated beta-galactosidase (SABGAL) is an enzyme that is produced in cells as they age and enter a state of senescence. It is used as a marker for cellular senescence and is used in research to study the aging process.
# Front: What is a DNA-dependent protein kinase?
#
# Back: A DNA-dependent protein kinase is an enzyme that phosphorylates proteins in response to changes in the DNA sequence. It is involved in the regulation of gene expression and plays a role in the control of cell cycle progression.
# Front: What is senescence?
# Back: Senescence is the process of aging and the associated decline in physical and mental functioning that occurs over time. It is a natural part of the life cycle and is characterized by a decrease in the ability to respond to stress, increased vulnerability to disease, and a decrease in fertility.
# Front: What does BGI stand for?
# Back: BGI stands for Beijing Genomics Institute. It is a Chinese genomics and biotechnology research institute.
# Front: What is hydrogen peroxide?
#
# Back: Hydrogen peroxide is a chemical compound with the formula H2O2. It is a colorless liquid that is slightly more viscous than water and has strong oxidizing properties. It is used as a bleaching agent, antiseptic, and disinfectant.
# Front: What is the gene symbol for the gene encoding the human histone deacetylase 3?
#
# Back: SB203580
# CPU times: user 3.3 s, sys: 297 ms, total: 3.59 s
# Wall time: 24min 58s

# %% [markdown]
# ## Generate ankis visually

# %%
import genanki

# %%
model_id = 1607392319 # random number generated
deck_id = 3807392343

anki_model = genanki.Model(
  model_id,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

anki_deck = genanki.Deck(deck_id=deck_id, name=paper_title)

# %%
for anki in ankis:
    fields = [anki, ankis[anki]]
    new_note = genanki.Note(anki_model, fields, )
    anki_deck.add_note(new_note)

# %%
from slugify import slugify
slugify(paper_title)
# Out:
# 'loss-of-epigenetic-information-as-a-cause-of-mammalian-aging'

# %%
genanki.Package(anki_deck).write_to_file(f'{slugify(paper_title)}.apkg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 genanki.Package(anki_deck).write_to_file(f'{slugify(paper_title)}.apkg')
#
# NameError: name 'genanki' is not defined

# %%
len(ankis)
# Out:
# 424
